# 2017-03-31 20:45:00  16472.441406
# 2017-03-31 21:00:00  16406.937500
# 2017-03-31 21:15:00  16301.363281
# 2017-03-31 21:30:13  15919.153320
# 2017-03-31 21:45:00  15444.175781
# 2017-03-31 22:00:00  15412.195312
# 2017-03-31 22:15:00  15146.839844
# 2017-03-31 22:30:00  15376.103516
# 2017-03-31 22:45:00  15307.500000
# 2017-03-31 23:00:00  15187.699219
# 2017-03-31 23:15:00  14114.250000
# 2017-03-31 23:30:00  14364.056641
# 2017-03-31 23:45:00  14413.179688
#
# [113856 rows x 1 columns]

# %%
hourly = temp_df.resample('H').max()

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=[10,5])

df =hourly
ax.plot(df.index,df['Demand'])

data = df['Demand'].iloc[:14000]

# %%
from pyFTS.common import Util as cUtil
from pyFTS.benchmarks import benchmarks as bchmk, Util as bUtil
from pyFTS.partitioners import Util as pUtil

from pyFTS.models import sadaei

# %%
from pyFTS.common import Transformations

tdiff = Transformations.Differential(1)

boxcox = Transformations.BoxCox(0)

# %%
from pyFTS.partitioners import CMeans, Grid, FCM, Huarng, Entropy, Util

# %%
l=[]

# %%
from pyFTS.benchmarks import Measures
from pyFTS.common import Membership, Util
from pyFTS.partitioners import Grid,Huarng,FCM,Entropy

all_methods = [Grid.GridPartitioner, Entropy.EntropyPartitioner, FCM.FCMPartitioner, Huarng.HuarngPartitioner]

mfs = [Membership.trimf, Membership.gaussmf, Membership.trapmf]

# %%
def explore_partitioners(data, npart, methods=None, mf=None, transformation=None,
                         size=[12, 10], save=False, file=None):
    """
    Create partitioners for the mf membership functions and npart partitions and show the partitioning images.
    :data: Time series data
    :npart: Maximum number of partitions of the universe of discourse
    :methods: A list with the partitioning methods to be used
    :mf: A list with the membership functions to be used
    :transformation: a transformation to be used in partitioner
    :size: list, the size of the output image [width, height]
    :save: boolean, if the image will be saved on disk
    :file: string, the file path to save the image
    :return: the list of the built partitioners
    """
    if methods is None:
        methods = all_methods

    if mf is None:
        mf = mfs

    objs = []

    for p in methods:
        for m in mf:
            obj = p(data=data, npart=npart, func=m, transformation=transformation)
            obj.name = obj.name  + " - " + obj.membership_function.__name__
            objs.append(obj)

    #plot_partitioners(data, objs, size, save, file)

    return objs

# %%
l=[]

# %%
l=explore_partitioners(data,15)
l
# Out:
# [<pyFTS.partitioners.Grid.GridPartitioner at 0x7f2e3534d588>,
#  <pyFTS.partitioners.Grid.GridPartitioner at 0x7f2e3534d6d8>,
#  <pyFTS.partitioners.Grid.GridPartitioner at 0x7f2e3534f1d0>,
#  <pyFTS.partitioners.Entropy.EntropyPartitioner at 0x7f2e3534f898>,
#  <pyFTS.partitioners.Entropy.EntropyPartitioner at 0x7f2e3534ff60>,
#  <pyFTS.partitioners.Entropy.EntropyPartitioner at 0x7f2e353575f8>,
#  <pyFTS.partitioners.FCM.FCMPartitioner at 0x7f2e35357588>,
#  <pyFTS.partitioners.FCM.FCMPartitioner at 0x7f2e356c5f60>,
#  <pyFTS.partitioners.FCM.FCMPartitioner at 0x7f2e35355278>,
#  <pyFTS.partitioners.Huarng.HuarngPartitioner at 0x7f2e35355240>,
#  <pyFTS.partitioners.Huarng.HuarngPartitioner at 0x7f2e35355940>,
#  <pyFTS.partitioners.Huarng.HuarngPartitioner at 0x7f2e33650588>]

# %%
print(len(l))
# Out:
# 12

# %%
fuzzy_sets

# %%
l[0]

# %%
fuzzy_sets = Grid.GridPartitioner(data=data, npart=15)
#fuzzy_sets2 = Grid.GridPartitioner(data=data, npart=15, transformation=boxcox)

#pUtil.plot_partitioners(data, [fuzzy_sets,fuzzy_sets2])

# %%
fuzzy_sets1 = FCM.FCMPartitioner(data=data, npart=8)
fuzzy_sets2 = Grid.GridPartitioner(data=data, npart=8)
fuzzy_sets3 = Grid.GridPartitioner(data=data, npart=8)
fuzzy_sets4 = Grid.GridPartitioner(data=data, npart=8)
fuzzy_sets = Grid.GridPartitioner(data=data, npart=8)

# %%
model1 = sadaei.ExponentialyWeightedFTS("Exponentialy Weighted FTS",partitioner=fuzzy_sets)
model1.fit(data, order=3)

print(model1)
# Out:
# [ 17:55:01] Start training
# [ 17:55:01] Starting batch 1
# [ 17:55:02] Finish batch 1
# [ 17:55:02] Starting batch 2
# [ 17:55:02] Finish batch 2
# [ 17:55:02] Starting batch 3
# [ 17:55:02] Finish batch 3
# [ 17:55:02] Starting batch 4
# [ 17:55:02] Finish batch 4
# [ 17:55:02] Starting batch 5
# [ 17:55:03] Finish batch 5
# [ 17:55:03] Starting batch 6
# [ 17:55:03] Finish batch 6
# [ 17:55:03] Starting batch 7
# [ 17:55:03] Finish batch 7
# [ 17:55:03] Starting batch 8
# [ 17:55:03] Finish batch 8
# [ 17:55:03] Starting batch 9
# [ 17:55:04] Finish batch 9
# [ 17:55:04] Starting batch 10
# [ 17:55:04] Finish batch 10
# [ 17:55:04] Finish training
# Exponentialy Weighted FTS:
# A1 -> A1(0.21547080370609778),A1(0.23701788407670757),A2(0.26071967248437833),A2(0.28679163973281624)
# A10 -> A10(1.3120055991597598e-63),A10(1.443206159075736e-63),A10(1.5875267749833097e-63),A10(1.7462794524816408e-63),A10(1.920907397729805e-63),A10(2.1129981375027853e-63),A10(2.3242979512530643e-63),A10(2.556727746378371e-63),A10(2.8124005210162085e-63),A10(3.0936405731178297e-63),A10(3.403004630429613e-63),A10(3.7433050934725743e-63),A10(4.117635602819832e-63),A10(4.529399163101816e-63),A10(4.982339079411998e-63),A10(5.480572987353198e-63),A10(6.028630286088518e-63),A10(6.631493314697371e-63),A10(7.294642646167108e-63),A10(8.02410691078382e-63),A10(8.826517601862202e-63),A10(9.709169362048423e-63),A10(1.0680086298253267e-62),A10(1.1748094928078593e-62),A10(1.2922904420886454e-62),A10(1.4215194862975102e-62),A10(1.563671434927261e-62),A10(1.7200385784199874e-62),A10(1.8920424362619865e-62),A10(2.081246679888185e-62),A10(2.2893713478770035e-62),A10(2.5183084826647044e-62),A10(2.770139330931175e-62),A10(3.0471532640242925e-62),A10(3.3518685904267225e-62),A10(3.6870554494693953e-62),A10(4.055760994416335e-62),A10(4.461337093857969e-62),A10(4.907470803243766e-62),A10(5.398217883568143e-62),A10(5.938039671924958e-62),A10(

#  12344.476848871705,
#  12344.476848871705,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  12344.476848871705,
#  12344.476848871705,
#  12101.163270510218,
#  12344.476848871705,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  12344.476848871705,
#  12721.458245192875,
#  12344.476848871705,
#  12344.476848871705,
#  12721.458245192875,
#  12721.458245192875,
#  12344.476848871705,
#  12344.476848871705,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  11589.826543165142,
#  11589.826543165142,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  12344.476848871705,
#  12344.476848871705,
#  12101.163270510218,
#  12101.163270510218,
#  12344.476848871705,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  10973.459012192356,
#  11589.826543165142,
#  12344.476848871705,
#  12344.476848871705,
#  12101.163270510218,
#  11589.826543165142,
#  12344.476848871705,
#  12344.476848871705,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  10973.459012192356,
#  10973.459012192356,
#  10973.459012192356,
#  10973.459012192356,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  10973.459012192356,
#  11589.826543165142,
#  12101.163270510218,
#  12344.476848871705,
#  12344.476848871705,
#  12344.476848871705,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  11589.826543165142,
#  11589.826543165142,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  11589.826543165142,
#  12101.163270510218,
#  12101.163270510218,
#  11589.826543165142,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  12101.163270510218,
#  12344.476848871705,
#  12344.476848871705,
#  12344.476848871705,
#  12344.476848871705,
#  12101.163270510218,
#  11589.826543165142,
#  12101.163270510218,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  11589.826543165142,
#  11589.826543165142,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  11589.826543165142,
#  11589.826543165142,
#  12344.476848871705,
#  12344.476848871705,
#  12344.476848871705,
#  12344.476848871705,
#  12344.476848871705,
#  12344.476848871705,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  12344.476848871705,
#  12344.476848871705,
#  12344.476848871705,
#  12101.163270510218,
#  12344.476848871705,
#  12344.476848871705,
#  12101.163270510218,
#  12101.163270510218,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  12101.163270510218,
#  11589.826543165142,
#  10973.459012192356,
#  10973.459012192356,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  10973.459012192356,
#  11589.826543165142,
#  11589.826543165142,
#  10973.459012192356,
#  11589.826543165142,
#  12344.476848871705,
#  12721.458245192875,
#  12344.476848871705,
#  12344.476848871705,
#  12344.476848871705,
#  12344.476848871705,
#  12344.476848871705,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  12344.476848871705,
#  12344.476848871705,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  11589.826543165142,
#  12101.163270510218,
#  12721.458245192875,
#  12721.458245192875,
#  12721.458245192875,
#  12721.458245192875,
#  12721.458245192875,
#  12721.458245192875,
#  12344.476848871705,
#  12101.163270510218,
#  11589.826543165142,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  11589.826543165142,
#  10973.459012192356,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  10973.459012192356,
#  10973.459012192356,
#  11589.826543165142,
#  11589.826543165142,
#  12344.476848871705,
#  12344.476848871705,
#  12101.163270510218,
#  12101.163270510218,
#  12344.476848871705,
#  12101.163270510218,
#  12101.163270510218,
#  11589.826543165142,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  12344.476848871705,
#  12344.476848871705,
#  12344.476848871705,
#  12344.476848871705,
#  12344.476848871705,
#  12101.163270510218,
#  12344.476848871705,
#  12344.476848871705,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  11589.826543165142,
#  10973.459012192356,
#  10973.459012192356,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  12721.458245192875,
#  12721.458245192875,
#  12344.476848871705,
#  12344.476848871705,
#  12344.476848871705,
#  12344.476848871705,
#  12344.476848871705,
#  12344.476848871705,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  10973.459012192356,
#  10973.459012192356,
#  10973.459012192356,
#  10973.459012192356,
#  10973.459012192356,
#  10973.459012192356,
#  11589.826543165142,
#  12344.476848871705,
#  12344.476848871705,
#  12344.476848871705,
#  12721.458245192875,
#  12344.476848871705,
#  12344.476848871705,
#  12344.476848871705,
#  12344.476848871705,
#  12101.163270510218,
#  12101.163270510218,
#  12101.163270510218,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  10234.227911764225,
#  10973.459012192356,
#  10973.459012192356,
#  10973.459012192356,
#  10973.459012192356,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  12101.163270510218,
#  12721.458245192875,
#  12721.458245192875,
#  12721.458245192875,
#  12721.458245192875,
#  12344.476848871705,
#  12344.476848871705,
#  12344.476848871705,
#  12101.163270510218,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  10973.459012192356,
#  10973.459012192356,
#  11589.826543165142,
#  11589.826543165142,
#  10234.227911764225,
#  10973.459012192356,
#  10234.227911764225,
#  10234.227911764225,
#  10973.459012192356,
#  12101.163270510218,
#  12344.476848871705,
#  12101.163270510218,
#  12101.163270510218,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  10973.459012192356,
#  10973.459012192356,
#  10973.459012192356,
#  10973.459012192356,
#  10973.459012192356,
#  10973.459012192356,
#  10973.459012192356,
#  10234.227911764225,
#  10234.227911764225,
#  10234.227911764225,
#  10234.227911764225,
#  10234.227911764225,
#  9599.430127572768,
#  9599.430127572768,
#  9599.430127572768,
#  10234.227911764225,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  12101.163270510218,
#  12101.163270510218,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  10973.459012192356,
#  10973.459012192356,
#  10973.459012192356,
#  10973.459012192356,
#  10973.459012192356,
#  10973.459012192356,
#  10234.227911764225,
#  10234.227911764225,
#  10973.459012192356,
#  10973.459012192356,
#  10973.459012192356,
#  10234.227911764225,
#  10234.227911764225,
#  10234.227911764225,
#  10234.227911764225,
#  10973.459012192356,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  10973.459012192356,
#  11589.826543165142,
#  10973.459012192356,
#  10973.459012192356,
#  10234.227911764225,
#  10234.227911764225,
#  10234.227911764225,
#  10234.227911764225,
#  10234.227911764225,
#  10973.459012192356,
#  10234.227911764225,
#  9599.430127572768,
#  9599.430127572768,
#  9599.430127572768,
#  10234.227911764225,
#  10234.227911764225,
#  10234.227911764225,
#  10234.227911764225,
#  9599.430127572768,
#  9599.430127572768,
#  10234.227911764225,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  11589.826543165142,
#  10973.459012192356,
#  10973.459012192356,
#  10234.227911764225,
#  10973.459012192356,
#  10234.227911764225,
#  10234.227911764225,
#  10973.459012192356,
#  10973.459012192356,
#  10973.459012192356,
#  10234.227911764225,
#  9599.430127572768,
#  10234.227911764225,
#  10234.227911764225,
#  9599.430127572768,
#  9599.430127572768,
#  9599.430127572768,
#  10234.227911764225,
#  10234.227911764225,
#  10234.227911764225,
#  11589.826543165142,
#  12101.163270510218,
#  10973.459012192356,
#  11589.826543165142,
#  10973.459012192356,
#  10973.459012192356,
#  10973.459012192356,
#  10234.227911764225,
#  10234.227911764225,
#  10234.227911764225,
#  10234.227911764225,
#  10973.459012192356,
#  10973.459012192356,
#  10973.459012192356,
#  10234.227911764225,
#  9599.430127572768,
#  9599.430127572768,
#  8898.624414627202,
#  8898.624414627202,
#  8898.624414627202,
#  8898.624414627202,
#  9599.430127572768,
#  8898.624414627202,
#  9599.430127572768,
#  10973.459012192356,
#  10973.459012192356,
#  10973.459012192356,
#  10973.459012192356,
#  9599.430127572768,
#  9599.430127572768,
#  8445.467783092154,
#  7741.500934692427,
#  7741.500934692427,
#  7271.387027512536,
#  7741.500934692427,
#  8445.467783092154,
#  8898.624414627202,
#  8898.624414627202,
#  8898.624414627202,
#  8445.467783092154,
#  8445.467783092154,
#  8445.467783092154,
#  8445.467783092154,
#  8445.467783092154,
#  8445.467783092154,
#  8445.467783092154,
#  ...]

# %%
from pyFTS.benchmarks import Measures as m

# %%
data2=data2[:-2]

# %%
m.mape(data2,forecast)
# Out:
# 2.1414208106818244

# %%
m.rmse(data2,forecast)
# Out:
# 277.85601461049157

# %%
H=hofts.HighOrderFTS.forecast("order",data)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-4c2530003a52> in <module>()
# ----> 1 H=hofts.HighOrderFTS.forecast("order",data)
#
# /usr/local/lib/python3.5/dist-packages/pyFTS/models/hofts.py in forecast(self, data, **kwargs)
#     109         l = len(data)
#     110
# --> 111         if l <= self.order:
#     112             return data
#     113
#
# AttributeError: 'str' object has no attribute 'order'

# %%
from pyFTS.partitioners import Grid

fs = Grid.GridPartitioner(data=data,npart=20,func=mf.trapmf)

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=[15,5])

fs.plot(ax)

# %%
hourly['First Difference']=hourly['Demand']-hourly['Demand'].shift(1)

# %%
hourly=hourly[hourly.Demand>8000]
hourly
#df = df[df.line_race != 0]
# Out:
#                            Demand  First Difference
# Date and Time
# 2014-01-01 00:00:00   9601.834961               NaN
# 2014-01-01 01:00:00   9384.458008       -217.376953
# 2014-01-01 02:00:00   8981.492188       -402.965820
# 2014-01-01 03:00:00   9020.666016         39.173828
# 2014-01-01 04:00:00   9462.734375        442.068359
# 2014-01-01 05:00:00   9670.680664        207.946289
# 2014-01-01 06:00:00   9874.875977        204.195312
# 2014-01-01 07:00:00   9435.500977       -439.375000
# 2014-01-01 08:00:00   9801.259766        365.758789
# 2014-01-01 09:00:00  10066.722656        265.462891
# 2014-01-01 10:00:00   9835.670898       -231.051758
# 2014-01-01 11:00:00  10352.171875        516.500977
# 2014-01-01 12:00:00  10013.296875       -338.875000
# 2014-01-01 13:00:00   9986.023438        -27.273438
# 2014-01-01 14:00:00   9055.225586       -930.797852
# 2014-01-01 15:00:00    274.060547
# 2014-01-01 16:00:00    -19.323242
# 2014-01-01 17:00:00    345.891602
# 2014-01-01 18:00:00    303.324219
# 2014-01-01 19:00:00    150.966797
# 2014-01-01 20:00:00   -559.211914
# 2014-01-01 21:00:00     25.178711
# 2014-01-01 22:00:00    306.681641
# 2014-01-01 23:00:00   -177.041992
# 2014-01-02 00:00:00   -344.629883
# 2014-01-02 01:00:00   -220.765625
# 2014-01-02 02:00:00   -161.873047
# 2014-01-02 03:00:00    -69.652344
# 2014-01-02 04:00:00    291.688477
# 2014-01-02 05:00:00     44.870117
# 2014-01-02 06:00:00    577.141602
#                           ...
# 2015-08-15 16:00:00    -61.125000
# 2015-08-15 17:00:00   -295.044922
# 2015-08-15 18:00:00    342.082031
# 2015-08-15 19:00:00    936.781250
# 2015-08-15 20:00:00   -539.455078
# 2015-08-15 21:00:00    312.123047
# 2015-08-15 22:00:00    220.519531
# 2015-08-15 23:00:00   -411.371094
# 2015-08-16 00:00:00    120.945312
# 2015-08-16 01:00:00   -131.197266
# 2015-08-16 02:00:00   -328.964844
# 2015-08-16 03:00:00   -166.195312
# 2015-08-16 04:00:00    -47.875977
# 2015-08-16 05:00:00    -78.657227
# 2015-08-16 06:00:00    105.498047
# 2015-08-16 07:00:00   -368.811523
# 2015-08-16 08:00:00   -141.745117
# 2015-08-16 09:00:00    308.122070
# 2015-08-16 10:00:00   -338.004883
# 2015-08-16 11:00:00    628.074219
# 2015-08-16 12:00:00   -248.957031
# 2015-08-16 13:00:00    -29.310547
# 2015-08-16 14:00:00   -140.412109
# 2015-08-16 15:00:00   -260.958984
# 2015-08-16 16:00:00     12.534180
# 2015-08-16 17:00:00   -385.113281
# 2015-08-16 18:00:00    516.842773
# 2015-08-16 19:00:00    268.545898
# 2015-08-16 20:00:00     79.361328
# 2015-08-16 21:00:00    500.563477
# Freq: H, Name: First Difference, Length: 14229, dtype: float64

# %%
from pyFTS.common import Membership as mf

# %%
from pyFTS.partitioners import Grid

fs = Grid.GridPartitioner(data=data,npart=10,transformation=tdiff)

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=[15,5])

fs.plot(ax)

# %%
from pyFTS.partitioners import Grid

fs = Grid.GridPartitioner(data=data,npart=10,transformation=tdiff)

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=[15,5])

fs.plot(ax)

# %%
from pyFTS.partitioners import CMeans, Grid, FCM, Huarng, Entropy, Util

# %%
fs = FCM.FCMPartitioner(data=data,npart=10,transformation=tdiff)

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=[40,15])

fs.plot(ax)
# Out:
# /usr/local/lib/python3.5/dist-packages/pyFTS/partitioners/partitioner.py:88: UserWarning: Attempting to set identical left==right results
# in singular transformations; automatically expanding.
# left=0.0, right=0.0
#   ax.set_xlim([self.min, self.max])

# %%
data
# Out:
# Date and Time
# 2014-01-01 00:00:00     9601.834961
# 2014-01-01 01:00:00     9384.458008
# 2014-01-01 02:00:00     8981.492188
# 2014-01-01 03:00:00     9020.666016
# 2014-01-01 04:00:00     9462.734375
# 2014-01-01 05:00:00     9670.680664
# 2014-01-01 06:00:00     9874.875977
# 2014-01-01 07:00:00     9435.500977
# 2014-01-01 08:00:00     9801.259766
# 2014-01-01 09:00:00    10066.722656
# 2014-01-01 10:00:00     9835.670898
# A10 -> A10,A11,A12,A13,A5,A6,A7,A8,A9
# A11 -> A10,A11,A12,A13,A14,A7,A8,A9
# A12 -> A10,A11,A12,A13,A14,A15,A8,A9
# A13 -> A10,A11,A12,A13,A14,A15,A9
# A14 -> A11,A12,A13,A14,A15,A16
# A15 -> A13,A14,A15,A16
# A16 -> A15,A16,A17
# A17 -> A16
# A2 -> A2,A3,A4,A5,A6,A7
# A3 -> A2,A3,A4,A5,A6,A7,A8,A9
# A4 -> A2,A3,A4,A5,A6,A7,A8,A9
# A5 -> A10,A2,A3,A4,A5,A6,A7,A8,A9
# A6 -> A10,A11,A3,A4,A5,A6,A7,A8,A9
# A7 -> A10,A11,A4,A5,A6,A7,A8,A9
# A8 -> A10,A11,A12,A3,A5,A6,A7,A8,A9
# A9 -> A10,A11,A12,A13,A5,A6,A7,A8,A9

# %%
from pyFTS.common import Util as U

U.plot_rules(model, size=[15,5] , rules_by_axis=10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-213755de9a25> in <module>()
#       1 from pyFTS.common import Util as U
#       2
# ----> 3 U.plot_rules(model, size=[15,5] , rules_by_axis=10)
#
# AttributeError: module 'pyFTS.common.Util' has no attribute 'plot_rules'

# %%
model1.predict([15000,12000])
# Out:
# [15000, 12000]

# %%
X=np.arange()
X
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-45-bbaad346d027> in <module>()
# ----> 1 X=np.arange()
#       2 X
#
# TypeError: Required argument 'start' (pos 1) not found

# %%
X1=np.array(data.index.values)
X1
# Out:
# array(['2014-01-01T00:00:00.000000000', '2014-01-01T01:00:00.000000000',
#        '2014-01-01T02:00:00.000000000', ...,
#        '2015-08-23T10:00:00.000000000', '2015-08-23T11:00:00.000000000',
#        '2015-08-23T12:00:00.000000000'], dtype='datetime64[ns]')

# %%
data2=df['Demand'].iloc[14231:28000]
data2
# Out:
# Date and Time
# 2015-08-16 23:00:00    12118.385742
# 2015-08-17 00:00:00    12103.322266
# 2015-08-17 01:00:00    12424.018555
# 2015-08-17 02:00:00    12155.643555
# 2015-08-17 03:00:00    11896.458984
# 2015-08-17 04:00:00    11837.467773
# 2015-08-17 05:00:00    11965.365234
# 2015-08-17 06:00:00    11392.339844
# 2015-08-17 07:00:00    11020.130859
# 2015-08-17 08:00:00    11113.207031
# 2015-08-17 09:00:00    11278.945312
# 2015-08-17 10:00:00    11076.214844
# 2015-08-17 11:00:00    11348.360352
# 2015-08-17 12:00:00    11333.818359
# 2015-08-17 13:00:00    11352.953125
# 2015-08-17 14:00:00    11384.001953
# 2015-08-17 15:00:00    11518.625000
# 2015-08-17 16:00:00    11619.787109
# 2015-08-17 17:00:00    11206.758789
# 2015-08-17 18:00:00    11249.822266
# 2015-08-17 19:00:00    11283.008789
# 2015-08-17 20:00:00    11314.337891
# 2015-08-17 21:00:00    11269.773438
# 2015-08-17 22:00:00    11886.595703
# 2015-08-17 23:00:00    11581.523438
# 2015-08-18 00:00:00    11487.988281
# 2015-08-18 01:00:00    11669.599609
# 2015-08-18 02:00:00    11835.682617
# 2015-08-18 03:00:00    11348.734375
# 2015-08-18 04:00:00    11371.466797
#                            ...
# 2017-03-11 10:00:00    11402.890625
# 2017-03-11 11:00:00    11364.685547
# 2017-03-11 12:00:00    11584.500977
# 2017-03-11 13:00:00    11462.261719
# 2017-03-11 14:00:00    10857.317383
# 2017-03-11 15:00:00    10679.853516
# 2017-03-11 16:00:00    10107.369141
# 2017-03-11 17:00:00    10240.074219
# 2017-03-11 18:00:00    11157.521484
# 2017-03-11 19:00:00    11807.117188
# 2017-03-11 20:00:00    10795.126953
# 2017-03-11 21:00:00    10518.500977
# 2017-03-11 22:00:00    10999.009766
# 2017-03-11 23:00:00    11058.584961
# 2017-03-12 00:00:00    10369.778320
# 2017-03-12 01:00:00    10220.932617
# 2017-03-12 02:00:00    10042.203125
# 2017-03-12 03:00:00     9920.604492
# 2017-03-12 04:00:00    10002.722656
# 2017-03-12 05:00:00    10927.564453
# 2017-03-12 06:00:00    11396.904297
# 2017-03-12 07:00:00    11671.966797
# 2017-03-12 08:00:00    11249.533203
# 2017-03-12 09:00:00    11936.980469
# 2017-03-12 10:00:00    12006.703125
# 2017-03-12 11:00:00    11950.271484
# 2017-03-12 12:00:00    11461.140625
# 2017-03-12 13:00:00    11074.624023
# 2017-03-12 14:00:00    10433.632812
# 2017-03-12 15:00:00     9962.336914
# Freq: H, Name: Demand, Length: 13769, dtype: float64

# %%
X2=np.array(data2.index.values)
X2
# Out:
# array(['2015-08-16T23:00:00.000000000', '2015-08-17T00:00:00.000000000',
#        '2015-08-17T01:00:00.000000000', ...,
#        '2017-03-31T21:00:00.000000000', '2017-03-31T22:00:00.000000000',
#        '2017-03-31T23:00:00.000000000'], dtype='datetime64[ns]')

# %%
forecast = model1.predict(data2)
forecast.insert(0,None)
#forecasts=forecasts[:14200]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-23-7e41c2c02ec2> in <module>()
# ----> 1 forecast = model1.predict(data2)
#       2 forecast.insert(0,None)
#       3 #forecasts=forecasts[:14200]
#
# /usr/local/lib/python3.5/dist-packages/pyFTS/common/fts.py in predict(self, data, **kwargs)
#      79
#      80             if type == 'point' and steps_ahead == None:
# ---> 81                 return self.forecast(data, **kwargs)
#      82             elif type == 'point' and steps_ahead != None:
#      83                 return self.forecast_ahead(data, steps_ahead, **kwargs)
#
# /usr/local/lib/python3.5/dist-packages/pyFTS/models/hofts.py in forecast(self, data, **kwargs)
#     120                 tmp = []
#     121                 if flrg.get_key() not in self.flrgs:
# --> 122                     tmp.append(self.sets[flrg.LHS[-1]].centroid)
#     123                 else:
#     124                     flrg = self.flrgs[flrg.get_key()]
#
# IndexError: list index out of range

# %%
forecast

# %%
datatemp=data[:14200]
datatemp
# Out:
# Date and Time
# 2014-01-01 00:00:00     9601.834961
# 2014-01-01 01:00:00     9384.458008
# 2014-01-01 02:00:00     8981.492188
# 2014-01-01 03:00:00     9020.666016
# 2014-01-01 04:00:00     9462.734375
# 2014-01-01 05:00:00     9670.680664
# 2014-01-01 06:00:00     9874.875977
# 2014-01-01 07:00:00     9435.500977
# 2014-01-01 08:00:00     9801.259766
# 2014-01-01 09:00:00    10066.722656
# 2014-01-01 10:00:00     9835.670898
# 2014-01-01 11:00:00    10352.171875
# 2014-01-01 12:00:00    10013.296875
# 2014-01-01 13:00:00     9986.023438
# 2014-01-01 14:00:00     9055.225586
# 2014-01-01 15:00:00     9329.286133
# 2014-01-01 16:00:00     9309.962891
# 2014-01-01 17:00:00     9655.854492
# 2014-01-01 18:00:00     9959.178711
# 2014-01-01 19:00:00    10110.145508
# 2014-01-01 20:00:00     9550.933594
# 2014-01-01 21:00:00     9576.112305
# 2014-01-01 22:00:00     9882.793945
# 2014-01-01 23:00:00     9705.751953
# 2014-01-02 00:00:00     9361.122070
# 2014-01-02 01:00:00     9140.356445
# 2014-01-02 02:00:00     8978.483398
# 2014-01-02 03:00:00     8908.831055
# 2014-01-02 04:00:00     9200.519531
# 2014-01-02 05:00:00     9245.389648
#                            ...
# 2015-08-14 10:00:00    12533.200195
# 2015-08-14 11:00:00    12553.421875
# 2015-08-14 12:00:00    12282.685547
# 2015-08-14 13:00:00    12215.278320
# 2015-08-14 14:00:00    12382.625000
# 2015-08-14 15:00:00    12121.810547
# 2015-08-14 16:00:00    12042.049805
# 2015-08-14 17:00:00    11617.418945
# 2015-08-14 18:00:00    12111.443359
# 2015-08-14 19:00:00    12328.777344
# 2015-08-14 20:00:00    11929.971680
# 2015-08-14 21:00:00    12407.129883
# 2015-08-14 22:00:00    12197.718750
# 2015-08-14 23:00:00    12175.607422
# 2015-08-15 00:00:00    12398.820312
# 2015-08-15 01:00:00    12283.001953
# 2015-08-15 02:00:00    12397.507812
# 2015-08-15 03:00:00    12290.726562
# 2015-08-15 04:00:00    12069.337891
# 2015-08-15 05:00:00    12024.685547
# 2015-08-15 06:00:00    12278.238281
# 2015-08-15 07:00:00    11595.774414
# 2015-08-15 08:00:00    11800.473633
# 2015-08-15 09:00:00    11897.833008
# 2015-08-15 10:00:00    11929.432617
# 2015-08-15 11:00:00    11781.036133
# 2015-08-15 12:00:00    11922.898438
# 2015-08-15 13:00:00    11406.511719
# 2015-08-15 14:00:00    10763.217773
# 2015-08-15 15:00:00    11554.460938
# Freq: H, Name: Demand, Length: 14200, dtype: float64

# %%
X2=np.array(datatemp.index.values)

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=[40,20])





ax.plot(X2,data,c = "orange",label="Original data")
ax.plot(X2,forecasts, label="Forecasts")

#legend(handles=[orig, pred])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-6c0d22155062> in <module>()
#       6
#       7
# ----> 8 ax.plot(X2,data,c = "orange",label="Original data")
#       9 ax.plot(X2,forecasts, label="Forecasts")
#      10
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1783                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1784                         RuntimeWarning, stacklevel=2)
# -> 1785             return func(ax, *args, **kwargs)
#    1786
#    1787         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, *args, **kwargs)
#    1602         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
#    1603
# -> 1604         for line in self._get_lines(*args, **kwargs):
#    1605             self.add_line(line)
#    1606             lines.append(line)
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     391                 this += args[0],
#     392                 args = args[1:]
# --> 393             yield from self._plot_args(this, kwargs)
#     394
#     395
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     368             x, y = index_of(tup[-1])
#     369
# --> 370         x, y = self._xy_from_xy(x, y)
#     371
#     372         if self.command == 'plot':
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     229         if x.shape[0] != y.shape[0]:
#     230             raise ValueError("x and y must have same first dimension, but "
# --> 231                              "have shapes {} and {}".format(x.shape, y.shape))
#     232         if x.ndim > 2 or y.ndim > 2:
#     233             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (14200,) and (14232,)
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x7fc4ca1fd1e0> (for post_execute):
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/matplotlib/pyplot.py in post_execute()
#     107             def post_execute():
#     108                 if matplotlib.is_interactive():
# --> 109                     draw_all()
#     110
#     111             # IPython >= 2
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     130         for f_mgr in cls.get_all_fig_managers():
#     131             if force or f_mgr.canvas.figure.stale:
# --> 132                 f_mgr.canvas.draw_idle()
#     133
#     134 atexit.register(Gcf.destroy_all)
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    1897         if not self._is_idle_drawing:
#    1898             with self._idle_draw_cntx():
# -> 1899                 self.draw(*args, **kwargs)
#    1900
#    1901     def draw_cursor(self, event):
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/backends/backend_agg.py in draw(self)
#     400         toolbar = self.toolbar
#     401         try:
# --> 402             self.figure.draw(self.renderer)
#     403             # A GUI class may be need to update a window using this draw, so
#     404             # don't forget to call the superclass.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/figure.py in draw(self, renderer)
#    1650
#    1651             mimage._draw_list_compositing_images(
# -> 1652                 renderer, self, artists, self.suppressComposite)
#    1653
#    1654             renderer.close_group('figure')
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2602             renderer.stop_rasterizing()
#    2603
# -> 2604         mimage._draw_list_compositing_images(renderer, self, artists)
#    2605
#    2606         renderer.close_group('axes')
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1185         ticks_to_draw = self._update_ticks(renderer)
#    1186         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
# -> 1187                                                                 renderer)
#    1188
#    1189         for tick in ticks_to_draw:
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axis.py in _get_tick_bboxes(self, ticks, renderer)
#    1123         for tick in ticks:
#    1124             if tick.label1On and tick.label1.get_visible():
# -> 1125                 extent = tick.label1.get_window_extent(renderer)
#    1126                 ticklabelBoxes.append(extent)
#    1127             if tick.label2On and tick.label2.get_visible():
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/text.py in get_window_extent(self, renderer, dpi)
#     927             raise RuntimeError('Cannot get window extent w/o renderer')
#     928
# --> 929         bbox, info, descent = self._get_layout(self._renderer)
#     930         x, y = self.get_unitless_position()
#     931         x, y = self.get_transform().transform_point((x, y))
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/text.py in _get_layout(self, renderer)
#     311                 w, h, d = renderer.get_text_width_height_descent(clean_line,
#     312                                                         self._fontproperties,
# --> 313                                                         ismath=ismath)
#     314             else:
#     315                 w, h, d = 0, 0, 0
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/backends/backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     207             fontsize = prop.get_size_in_points()
#     208             w, h, d = texmanager.get_text_width_height_descent(
# --> 209                 s, fontsize, renderer=self)
#     210             return w, h, d
#     211
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/texmanager.py in get_text_width_height_descent(self, tex, fontsize, renderer)
#     462         else:
#     463             # use dviread. It sometimes returns a wrong descent.
# --> 464             dvifile = self.make_dvi(tex, fontsize)
#     465             with dviread.Dvi(dvifile, 72 * dpi_fraction) as dvi:
#     466                 page = next(iter(dvi))
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/texmanager.py in make_dvi(self, tex, fontsize)
#     326                 self._run_checked_subprocess(
#     327                     ["latex", "-interaction=nonstopmode", "--halt-on-error",
# --> 328                      texfile], tex)
#     329             for fname in glob.glob(basefile + '*'):
#     330                 if not fname.endswith(('dvi', 'tex')):
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/texmanager.py in _run_checked_subprocess(self, command, tex)
#     296             report = subprocess.check_output(command,
#     297                                              cwd=self.texcache,
# --> 298                                              stderr=subprocess.STDOUT)
#     299         except subprocess.CalledProcessError as exc:
#     300             raise RuntimeError(
#
# /usr/lib/python3.5/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     624
#     625     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 626                **kwargs).stdout
#     627
#     628
#
# /usr/lib/python3.5/subprocess.py in run(input, timeout, check, *popenargs, **kwargs)
#     691         kwargs['stdin'] = PIPE
#     692
# --> 693     with Popen(*popenargs, **kwargs) as process:
#     694         try:
#     695             stdout, stderr = process.communicate(input, timeout=timeout)
#
# /usr/lib/python3.5/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds)
#     945                                 c2pread, c2pwrite,
#     946                                 errread, errwrite,
# --> 947                                 restore_signals, start_new_session)
#     948         except:
#     949             # Cleanup if the child failed starting.
#
# /usr/lib/python3.5/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1549                             else:
#    1550                                 err_msg += ': ' + repr(orig_executable)
# -> 1551                     raise child_exception_type(errno_num, err_msg)
#    1552                 raise child_exception_type(err_msg)
#    1553
#
# FileNotFoundError: [Errno 2] No such file or directory: 'latex'
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/.local/lib/python3.5/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/.local/lib/python3.5/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     239
#     240     if 'png' in formats:
# --> 241         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     242     if 'retina' in formats or 'png2x' in formats:
#     243         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/.local/lib/python3.5/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     123
#     124     bytes_io = BytesIO()
# --> 125     fig.canvas.print_figure(bytes_io, **kw)
#     126     data = bytes_io.getvalue()
#     127     if fmt == 'svg':
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2047                         orientation=orientation,
#    2048                         dryrun=True,
# -> 2049                         **kwargs)
#    2050                     renderer = self.figure._cachedRenderer
#    2051                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     508
#     509         """
# --> 510         FigureCanvasAgg.draw(self)
#     511         renderer = self.get_renderer()
#     512
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/backends/backend_agg.py in draw(self)
#     400         toolbar = self.toolbar
#     401         try:
# --> 402             self.figure.draw(self.renderer)
#     403             # A GUI class may be need to update a window using this draw, so
#     404             # don't forget to call the superclass.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/figure.py in draw(self, renderer)
#    1650
#    1651             mimage._draw_list_compositing_images(
# -> 1652                 renderer, self, artists, self.suppressComposite)
#    1653
#    1654             renderer.close_group('figure')
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2602             renderer.stop_rasterizing()
#    2603
# -> 2604         mimage._draw_list_compositing_images(renderer, self, artists)
#    2605
#    2606         renderer.close_group('axes')
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1185         ticks_to_draw = self._update_ticks(renderer)
#    1186         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
# -> 1187                                                                 renderer)
#    1188
#    1189         for tick in ticks_to_draw:
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axis.py in _get_tick_bboxes(self, ticks, renderer)
#    1123         for tick in ticks:
#    1124             if tick.label1On and tick.label1.get_visible():
# -> 1125                 extent = tick.label1.get_window_extent(renderer)
#    1126                 ticklabelBoxes.append(extent)
#    1127             if tick.label2On and tick.label2.get_visible():
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/text.py in get_window_extent(self, renderer, dpi)
#     927             raise RuntimeError('Cannot get window extent w/o renderer')
#     928
# --> 929         bbox, info, descent = self._get_layout(self._renderer)
#     930         x, y = self.get_unitless_position()
#     931         x, y = self.get_transform().transform_point((x, y))
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/text.py in _get_layout(self, renderer)
#     311                 w, h, d = renderer.get_text_width_height_descent(clean_line,
#     312                                                         self._fontproperties,
# --> 313                                                         ismath=ismath)
#     314             else:
#     315                 w, h, d = 0, 0, 0
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/backends/backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     207             fontsize = prop.get_size_in_points()
#     208             w, h, d = texmanager.get_text_width_height_descent(
# --> 209                 s, fontsize, renderer=self)
#     210             return w, h, d
#     211
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/texmanager.py in get_text_width_height_descent(self, tex, fontsize, renderer)
#     462         else:
#     463             # use dviread. It sometimes returns a wrong descent.
# --> 464             dvifile = self.make_dvi(tex, fontsize)
#     465             with dviread.Dvi(dvifile, 72 * dpi_fraction) as dvi:
#     466                 page = next(iter(dvi))
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/texmanager.py in make_dvi(self, tex, fontsize)
#     326                 self._run_checked_subprocess(
#     327                     ["latex", "-interaction=nonstopmode", "--halt-on-error",
# --> 328                      texfile], tex)
#     329             for fname in glob.glob(basefile + '*'):
#     330                 if not fname.endswith(('dvi', 'tex')):
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/texmanager.py in _run_checked_subprocess(self, command, tex)
#     296             report = subprocess.check_output(command,
#     297                                              cwd=self.texcache,
# --> 298                                              stderr=subprocess.STDOUT)
#     299         except subprocess.CalledProcessError as exc:
#     300             raise RuntimeError(
#
# /usr/lib/python3.5/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     624
#     625     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 626                **kwargs).stdout
#     627
#     628
#
# /usr/lib/python3.5/subprocess.py in run(input, timeout, check, *popenargs, **kwargs)
#     691         kwargs['stdin'] = PIPE
#     692
# --> 693     with Popen(*popenargs, **kwargs) as process:
#     694         try:
#     695             stdout, stderr = process.communicate(input, timeout=timeout)
#
# /usr/lib/python3.5/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds)
#     945                                 c2pread, c2pwrite,
#     946                                 errread, errwrite,
# --> 947                                 restore_signals, start_new_session)
#     948         except:
#     949             # Cleanup if the child failed starting.
#
# /usr/lib/python3.5/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1549                             else:
#    1550                                 err_msg += ': ' + repr(orig_executable)
# -> 1551                     raise child_exception_type(errno_num, err_msg)
#    1552                 raise child_exception_type(err_msg)
#    1553
#
# FileNotFoundError: [Errno 2] No such file or directory: 'latex'

# %%
from pyFTS.benchmarks import Measures as m

# %%
m.mape(data2,forecasts)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-d79639e9682f> in <module>()
# ----> 1 m.mape(data2,forecasts)
#
# NameError: name 'forecasts' is not defined

# %%
from pyFTS.partitioners import CMeans, Grid, FCM, Huarng, Entropy, Util as pUtil
from pyFTS.common import Membership as mf
from pyFTS.benchmarks import benchmarks as bchmk

# %%
"""
2. Data transformations

In the package pyFTS.common.Transformations several data transformations can be used for the pre-processing and/or post-processing data, which directly impacts the partitioning of the universe of discourse.
"""
from pyFTS.common import Transformations
tdiff = Transformations.Differential(2)

# %%
"""
2. Data transformations

In the package pyFTS.common.Transformations several data transformations can be used for the pre-processing and/or post-processing data, which directly impacts the partitioning of the universe of discourse.
"""
from pyFTS.common import Transformations
tdiff = Transformations.Scale(1)

# %%
"""
2. Data transformations

In the package pyFTS.common.Transformations several data transformations can be used for the pre-processing and/or post-processing data, which directly impacts the partitioning of the universe of discourse.
"""
from pyFTS.common import Transformations
tdiff = Transformations.BoxCox(1)

# %%
part = pUtil.explore_partitioners(data, 8, methods=[Grid.GridPartitioner], 
                                  mf=[mf.trimf, mf.trapmf, mf.gaussmf])
# Out:
# /usr/local/lib/python3.5/dist-packages/matplotlib/font_manager.py:1238: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-943cdfbaf620> in <module>()
#       1 part = pUtil.explore_partitioners(data, 8, methods=[Grid.GridPartitioner],
# ----> 2                                   mf=[mf.trimf, mf.trapmf, mf.gaussmf])
#
# /usr/local/lib/python3.5/dist-packages/pyFTS/partitioners/Util.py in explore_partitioners(data, npart, methods, mf, tam, save, file)
#      68             objs.append(obj)
#      69
# ---> 70     plot_partitioners(data, objs, tam, save, file)
#      71
#      72     return objs
#
# /usr/local/lib/python3.5/dist-packages/pyFTS/partitioners/Util.py in plot_partitioners(data, objs, tam, save, file)
#      50     sets = [k.sets for k in objs]
#      51     titles = [k.name for k in objs]
# ---> 52     plot_sets(data, sets, titles, tam, save, file)
#      53
#      54
#
# /usr/local/lib/python3.5/dist-packages/pyFTS/partitioners/Util.py in plot_sets(data, sets, titles, tam, save, file)
#      42         ax.xaxis.set_ticks(x)
#      43
# ---> 44     plt.tight_layout()
#      45
#      46     Util.show_and_save_image(fig, file, save)
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/pyplot.py in tight_layout(pad, h_pad, w_pad, rect)
#    1379         labels) will fit into. Default is (0, 0, 1, 1).
#    1380     """
# -> 1381     gcf().tight_layout(pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#    1382
#    1383
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/figure.py in tight_layout(self, renderer, pad, h_pad, w_pad, rect)
#    2368         kwargs = get_tight_layout_figure(
#    2369             self, self.axes, subplotspec_list, renderer,
# -> 2370             pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#    2371         self.subplots_adjust(**kwargs)
#    2372
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/tight_layout.py in get_tight_layout_figure(fig, axes_list, subplotspec_list, renderer, pad, h_pad, w_pad, rect)
#     354                                      subplot_list=subplot_list,
#     355                                      ax_bbox_list=ax_bbox_list,
# --> 356                                      pad=pad, h_pad=h_pad, w_pad=w_pad)
#     357
#     358     if rect is not None:
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/tight_layout.py in auto_adjust_subplotpars(fig, renderer, nrows_ncols, num1num2_list, subplot_list, ax_bbox_list, pad, h_pad, w_pad, rect)
#     112             continue
#     113
# --> 114         tight_bbox_raw = union([ax.get_tightbbox(renderer) for ax in subplots
#     115                                 if ax.get_visible()])
#     116         tight_bbox = TransformedBbox(tight_bbox_raw,
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/tight_layout.py in <listcomp>(.0)
#     113
#     114         tight_bbox_raw = union([ax.get_tightbbox(renderer) for ax in subplots
# --> 115                                 if ax.get_visible()])
#     116         tight_bbox = TransformedBbox(tight_bbox_raw,
#     117                                      fig.transFigure.inverted())
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axes/_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists)
#    4197             self.apply_aspect()
#    4198
# -> 4199         bb_xaxis = self.xaxis.get_tightbbox(renderer)
#    4200         if bb_xaxis:
#    4201             bb.append(bb_xaxis)
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axis.py in get_tightbbox(self, renderer)
#    1140         ticks_to_draw = self._update_ticks(renderer)
#    1141
# -> 1142         self._update_label_position(renderer)
#    1143
#    1144         # go back to just this axis's tick labels
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axis.py in _update_label_position(self, renderer)
#    1932         # get bounding boxes for this axis and any siblings
#    1933         # that have been set by `fig.align_xlabels()`
# -> 1934         bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    1935
#    1936         x, y = self.label.get_position()
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axis.py in _get_tick_boxes_siblings(self, renderer)
#    1917         for nn, axx in enumerate(grp.get_siblings(self.axes)):
#    1918             ticks_to_draw = axx.xaxis._update_ticks(renderer)
# -> 1919             tlb, tlb2 = axx.xaxis._get_tick_bboxes(ticks_to_draw, renderer)
#    1920             bboxes.extend(tlb)
#    1921             bboxes2.extend(tlb2)
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axis.py in _get_tick_bboxes(self, ticks, renderer)
#    1123         for tick in ticks:
#    1124             if tick.label1On and tick.label1.get_visible():
# -> 1125                 extent = tick.label1.get_window_extent(renderer)
#    1126                 ticklabelBoxes.append(extent)
#    1127             if tick.label2On and tick.label2.get_visible():
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/text.py in get_window_extent(self, renderer, dpi)
#     927             raise RuntimeError('Cannot get window extent w/o renderer')
#     928
# --> 929         bbox, info, descent = self._get_layout(self._renderer)
#     930         x, y = self.get_unitless_position()
#     931         x, y = self.get_transform().transform_point((x, y))
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/text.py in _get_layout(self, renderer)
#     311                 w, h, d = renderer.get_text_width_height_descent(clean_line,
#     312                                                         self._fontproperties,
# --> 313                                                         ismath=ismath)
#     314             else:
#     315                 w, h, d = 0, 0, 0
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/backends/backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     207             fontsize = prop.get_size_in_points()
#     208             w, h, d = texmanager.get_text_width_height_descent(
# --> 209                 s, fontsize, renderer=self)
#     210             return w, h, d
#     211
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/texmanager.py in get_text_width_height_descent(self, tex, fontsize, renderer)
#     462         else:
#     463             # use dviread. It sometimes returns a wrong descent.
# --> 464             dvifile = self.make_dvi(tex, fontsize)
#     465             with dviread.Dvi(dvifile, 72 * dpi_fraction) as dvi:
#     466                 page = next(iter(dvi))
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/texmanager.py in make_dvi(self, tex, fontsize)
#     326                 self._run_checked_subprocess(
#     327                     ["latex", "-interaction=nonstopmode", "--halt-on-error",
# --> 328                      texfile], tex)
#     329             for fname in glob.glob(basefile + '*'):
#     330                 if not fname.endswith(('dvi', 'tex')):
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/texmanager.py in _run_checked_subprocess(self, command, tex)
#     296             report = subprocess.check_output(command,
#     297                                              cwd=self.texcache,
# --> 298                                              stderr=subprocess.STDOUT)
#     299         except subprocess.CalledProcessError as exc:
#     300             raise RuntimeError(
#
# /usr/lib/python3.5/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     624
#     625     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 626                **kwargs).stdout
#     627
#     628
#
# /usr/lib/python3.5/subprocess.py in run(input, timeout, check, *popenargs, **kwargs)
#     691         kwargs['stdin'] = PIPE
#     692
# --> 693     with Popen(*popenargs, **kwargs) as process:
#     694         try:
#     695             stdout, stderr = process.communicate(input, timeout=timeout)
#
# /usr/lib/python3.5/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds)
#     945                                 c2pread, c2pwrite,
#     946                                 errread, errwrite,
# --> 947                                 restore_signals, start_new_session)
#     948         except:
#     949             # Cleanup if the child failed starting.
#
# /usr/lib/python3.5/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1549                             else:
#    1550                                 err_msg += ': ' + repr(orig_executable)
# -> 1551                     raise child_exception_type(errno_num, err_msg)
#    1552                 raise child_exception_type(err_msg)
#    1553
#
# FileNotFoundError: [Errno 2] No such file or directory: 'latex'
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x7fc9793df1e0> (for post_execute):
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.5/dist-packages/matplotlib/pyplot.py in post_execute()
#     107             def post_execute():
#     108                 if matplotlib.is_interactive():
# --> 109                     draw_all()
#     110
#     111             # IPython >= 2
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/_pylab_helpers.py in draw_all(cls, force)
#     130         for f_mgr in cls.get_all_fig_managers():
#     131             if force or f_mgr.canvas.figure.stale:
# --> 132                 f_mgr.canvas.draw_idle()
#     133
#     134 atexit.register(Gcf.destroy_all)
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    1897         if not self._is_idle_drawing:
#    1898             with self._idle_draw_cntx():
# -> 1899                 self.draw(*args, **kwargs)
#    1900
#    1901     def draw_cursor(self, event):
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/backends/backend_agg.py in draw(self)
#     400         toolbar = self.toolbar
#     401         try:
# --> 402             self.figure.draw(self.renderer)
#     403             # A GUI class may be need to update a window using this draw, so
#     404             # don't forget to call the superclass.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/figure.py in draw(self, renderer)
#    1650
#    1651             mimage._draw_list_compositing_images(
# -> 1652                 renderer, self, artists, self.suppressComposite)
#    1653
#    1654             renderer.close_group('figure')
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2602             renderer.stop_rasterizing()
#    2603
# -> 2604         mimage._draw_list_compositing_images(renderer, self, artists)
#    2605
#    2606         renderer.close_group('axes')
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1185         ticks_to_draw = self._update_ticks(renderer)
#    1186         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
# -> 1187                                                                 renderer)
#    1188
#    1189         for tick in ticks_to_draw:
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axis.py in _get_tick_bboxes(self, ticks, renderer)
#    1123         for tick in ticks:
#    1124             if tick.label1On and tick.label1.get_visible():
# -> 1125                 extent = tick.label1.get_window_extent(renderer)
#    1126                 ticklabelBoxes.append(extent)
#    1127             if tick.label2On and tick.label2.get_visible():
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/text.py in get_window_extent(self, renderer, dpi)
#     927             raise RuntimeError('Cannot get window extent w/o renderer')
#     928
# --> 929         bbox, info, descent = self._get_layout(self._renderer)
#     930         x, y = self.get_unitless_position()
#     931         x, y = self.get_transform().transform_point((x, y))
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/text.py in _get_layout(self, renderer)
#     311                 w, h, d = renderer.get_text_width_height_descent(clean_line,
#     312                                                         self._fontproperties,
# --> 313                                                         ismath=ismath)
#     314             else:
#     315                 w, h, d = 0, 0, 0
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/backends/backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     207             fontsize = prop.get_size_in_points()
#     208             w, h, d = texmanager.get_text_width_height_descent(
# --> 209                 s, fontsize, renderer=self)
#     210             return w, h, d
#     211
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/texmanager.py in get_text_width_height_descent(self, tex, fontsize, renderer)
#     462         else:
#     463             # use dviread. It sometimes returns a wrong descent.
# --> 464             dvifile = self.make_dvi(tex, fontsize)
#     465             with dviread.Dvi(dvifile, 72 * dpi_fraction) as dvi:
#     466                 page = next(iter(dvi))
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/texmanager.py in make_dvi(self, tex, fontsize)
#     326                 self._run_checked_subprocess(
#     327                     ["latex", "-interaction=nonstopmode", "--halt-on-error",
# --> 328                      texfile], tex)
#     329             for fname in glob.glob(basefile + '*'):
#     330                 if not fname.endswith(('dvi', 'tex')):
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/texmanager.py in _run_checked_subprocess(self, command, tex)
#     296             report = subprocess.check_output(command,
#     297                                              cwd=self.texcache,
# --> 298                                              stderr=subprocess.STDOUT)
#     299         except subprocess.CalledProcessError as exc:
#     300             raise RuntimeError(
#
# /usr/lib/python3.5/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     624
#     625     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 626                **kwargs).stdout
#     627
#     628
#
# /usr/lib/python3.5/subprocess.py in run(input, timeout, check, *popenargs, **kwargs)
#     691         kwargs['stdin'] = PIPE
#     692
# --> 693     with Popen(*popenargs, **kwargs) as process:
#     694         try:
#     695             stdout, stderr = process.communicate(input, timeout=timeout)
#
# /usr/lib/python3.5/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds)
#     945                                 c2pread, c2pwrite,
#     946                                 errread, errwrite,
# --> 947                                 restore_signals, start_new_session)
#     948         except:
#     949             # Cleanup if the child failed starting.
#
# /usr/lib/python3.5/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1549                             else:
#    1550                                 err_msg += ': ' + repr(orig_executable)
# -> 1551                     raise child_exception_type(errno_num, err_msg)
#    1552                 raise child_exception_type(err_msg)
#    1553
#
# FileNotFoundError: [Errno 2] No such file or directory: 'latex'
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~/.local/lib/python3.5/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/.local/lib/python3.5/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     239
#     240     if 'png' in formats:
# --> 241         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     242     if 'retina' in formats or 'png2x' in formats:
#     243         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/.local/lib/python3.5/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     123
#     124     bytes_io = BytesIO()
# --> 125     fig.canvas.print_figure(bytes_io, **kw)
#     126     data = bytes_io.getvalue()
#     127     if fmt == 'svg':
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2047                         orientation=orientation,
#    2048                         dryrun=True,
# -> 2049                         **kwargs)
#    2050                     renderer = self.figure._cachedRenderer
#    2051                     bbox_artists = kwargs.pop("bbox_extra_artists", None)
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     508
#     509         """
# --> 510         FigureCanvasAgg.draw(self)
#     511         renderer = self.get_renderer()
#     512
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/backends/backend_agg.py in draw(self)
#     400         toolbar = self.toolbar
#     401         try:
# --> 402             self.figure.draw(self.renderer)
#     403             # A GUI class may be need to update a window using this draw, so
#     404             # don't forget to call the superclass.
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/figure.py in draw(self, renderer)
#    1650
#    1651             mimage._draw_list_compositing_images(
# -> 1652                 renderer, self, artists, self.suppressComposite)
#    1653
#    1654             renderer.close_group('figure')
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2602             renderer.stop_rasterizing()
#    2603
# -> 2604         mimage._draw_list_compositing_images(renderer, self, artists)
#    2605
#    2606         renderer.close_group('axes')
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1185         ticks_to_draw = self._update_ticks(renderer)
#    1186         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
# -> 1187                                                                 renderer)
#    1188
#    1189         for tick in ticks_to_draw:
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/axis.py in _get_tick_bboxes(self, ticks, renderer)
#    1123         for tick in ticks:
#    1124             if tick.label1On and tick.label1.get_visible():
# -> 1125                 extent = tick.label1.get_window_extent(renderer)
#    1126                 ticklabelBoxes.append(extent)
#    1127             if tick.label2On and tick.label2.get_visible():
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/text.py in get_window_extent(self, renderer, dpi)
#     927             raise RuntimeError('Cannot get window extent w/o renderer')
#     928
# --> 929         bbox, info, descent = self._get_layout(self._renderer)
#     930         x, y = self.get_unitless_position()
#     931         x, y = self.get_transform().transform_point((x, y))
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/text.py in _get_layout(self, renderer)
#     311                 w, h, d = renderer.get_text_width_height_descent(clean_line,
#     312                                                         self._fontproperties,
# --> 313                                                         ismath=ismath)
#     314             else:
#     315                 w, h, d = 0, 0, 0
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/backends/backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     207             fontsize = prop.get_size_in_points()
#     208             w, h, d = texmanager.get_text_width_height_descent(
# --> 209                 s, fontsize, renderer=self)
#     210             return w, h, d
#     211
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/texmanager.py in get_text_width_height_descent(self, tex, fontsize, renderer)
#     462         else:
#     463             # use dviread. It sometimes returns a wrong descent.
# --> 464             dvifile = self.make_dvi(tex, fontsize)
#     465             with dviread.Dvi(dvifile, 72 * dpi_fraction) as dvi:
#     466                 page = next(iter(dvi))
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/texmanager.py in make_dvi(self, tex, fontsize)
#     326                 self._run_checked_subprocess(
#     327                     ["latex", "-interaction=nonstopmode", "--halt-on-error",
# --> 328                      texfile], tex)
#     329             for fname in glob.glob(basefile + '*'):
#     330                 if not fname.endswith(('dvi', 'tex')):
#
# /usr/local/lib/python3.5/dist-packages/matplotlib/texmanager.py in _run_checked_subprocess(self, command, tex)
#     296             report = subprocess.check_output(command,
#     297                                              cwd=self.texcache,
# --> 298                                              stderr=subprocess.STDOUT)
#     299         except subprocess.CalledProcessError as exc:
#     300             raise RuntimeError(
#
# /usr/lib/python3.5/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     624
#     625     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
# --> 626                **kwargs).stdout
#     627
#     628
#
# /usr/lib/python3.5/subprocess.py in run(input, timeout, check, *popenargs, **kwargs)
#     691         kwargs['stdin'] = PIPE
#     692
# --> 693     with Popen(*popenargs, **kwargs) as process:
#     694         try:
#     695             stdout, stderr = process.communicate(input, timeout=timeout)
#
# /usr/lib/python3.5/subprocess.py in __init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds)
#     945                                 c2pread, c2pwrite,
#     946                                 errread, errwrite,
# --> 947                                 restore_signals, start_new_session)
#     948         except:
#     949             # Cleanup if the child failed starting.
#
# /usr/lib/python3.5/subprocess.py in _execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, restore_signals, start_new_session)
#    1549                             else:
#    1550                                 err_msg += ': ' + repr(orig_executable)
# -> 1551                     raise child_exception_type(errno_num, err_msg)
#    1552                 raise child_exception_type(err_msg)
#    1553
#
# FileNotFoundError: [Errno 2] No such file or directory: 'latex'
